# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatesh-Sathya/1st_Repo/blob/main/Documentation_Practice_GoogleCollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Documentation

# %% [markdown]
# ## Styling Text

# %% [markdown]
# **This is a bold statement.**(double**)

# %% [markdown]
# *This is an ital;ic statement*(single *)

# %% [markdown]
# ~This is a strikethrough statement.~(Single~)

# %% [markdown]
# **This is a bolded statement with an *italic* word**

# %% [markdown]
# ***This is a bolded and italic statement***(triple ***)

# %% [markdown]
# This is a <sub>subscript</sub> text

# %% [markdown]
# This is a <sup>superscript</sup> text

# %% [markdown]
# This is an <ins>underlined</ins> text

# %% [markdown]
# # Quoting Text

# %% [markdown]
# Text that is not a quote
#
# > Text that is a quote(use >)

# %% [markdown]
# # Quoting code

# %% [markdown]
# Use `git status` to list all new or modified files that haven't yet been committed.

# %% [markdown]
# Some basic git commands are:
# ```
# git status
# git add
# git commit
# ```

# %% [markdown]
# # Supported color models & Links

# %% [markdown]
# The background color is `#RRGGBB` for light mode and `#0969DA` for dark mode. Refer to [this github link](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax#styling-text) for more information

# %% [markdown]
# # Line Breaks

# %% [markdown]
# hello
# world ( wrong )

# %% [markdown]
# hello
# world ( 2 spaces after hello )

# %% [markdown]
# hello
#
# world(same idea)

# %% [markdown]
# # Images

# %% [markdown]
# ## One way

# %% [markdown]
# ### Writing the thing yourself

# %% [markdown]
# ![Screenshot of a comment on a GitHub issue showing an image, added in the Markdown, of an Octocat smiling and raising a tentacle.](https://myoctocat.com/assets/images/base-octocat.svg)

# %% [markdown]
# ### Using issues in GITHUB

# %% [markdown]
# <img width="568" height="376" alt="Image" src="https://github.com/user-attachments/assets/9ea50672-73c2-4994-a012-e1f52bb03513" />

# %% [markdown]
# # Lists

# %% [markdown]
# ## 1. Ordered

# %% [markdown]
# - Ali
# - Muthu
# - Ram

# %% [markdown]
# ## 2. Ordered

# %% [markdown]
# 1. Tom
# 2. Dick
# 3. Harry

# %% [markdown]
# ## 3. Nested Lists

# %% [markdown]
# 1. Uno
#    - First
#      - Second

# %% [markdown]
# ## 4. Task List

# %% [markdown]
# - [x] #MC
# - [ ] do smtg
# - [ ] not done yet

# %% [markdown]
# # Alerts

# %% [markdown]
# > [!NOTE]
# > This is a note
#
# > [!WARNING]
# > This is a warning
#
# **Will only render on github**

# %%
print("Hello World")
