# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatesh-Sathya/1st_Repo/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #WELCOME

# %% [markdown]
# #HELLO

# %% [markdown]
# ###tung

# %%
def addtwo(a,b):
  return a+b

addtwo(3,5)
# Out:
# 8

# %%
1

# %% [markdown]
# #LOL
